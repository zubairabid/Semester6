# %%
import csv
import os
import pickle
from tqdm import tqdm

# %%
subdirs = ['Training','Development','Testing']
dir_prefix = os.path.join(os.getcwd(), 'AnnCorra')

# %%
def get_features(pos, featurelist, word):
    featuredict = {}
    featuredict['pos'] = pos
    featuredict['word'] = word
    featuresplit = featurelist.split('|')
    for feature in featuresplit:
        key = feature.split('-')[0]
        val = feature.split('-')[1]
#         if not (key == 'stype' or key == 'voicetype' or key == 'chunkType' or key == 'chunkId'):
        featuredict[key] = val
    return featuredict
    
for current in subdirs:
    all_sentences = []
    all_features = []
    all_ancorra_tags = []
    
    directory = os.path.join(dir_prefix, current)
    print("processing files in directory: ", directory)
    for file in tqdm(os.listdir(directory)):
        file = os.path.join(directory, file)
        with open(file, newline='') as csvfile:
            csvreader = csv.reader(csvfile, delimiter='\t')
            
            sentence = []
            ancorra_tags = []
            features = []
            
            for row in csvreader:
                if len(row) == 0:
                    all_sentences.append(sentence)
                    all_features.append(features)
                    all_ancorra_tags.append(ancorra_tags)
                    
                    sentence = []
                    features = []
                    ancorra_tags = []
                else:
                    try:
                        sentence.append(row[1])
                        features.append(get_features(row[4], row[5], row[1]))
                        ancorra_tags.append(row[7])
                    except:
                        print("Error with sentence in file:", file, ", no need to interfere")
    datadir = os.path.join(os.getcwd(), 'Data/')                    
    with open(datadir+current+'_sentences.pkl', 'wb') as dump:
        pickle.dump(all_sentences, dump)
    with open(datadir+current+'_features.pkl', 'wb') as dump:
        pickle.dump(all_features, dump)
    with open(datadir+current+'_ancorra_tags.pkl', 'wb') as dump:
        pickle.dump(all_ancorra_tags, dump)
        
    if current == 'Testing':
        testcases = {}
        testcases['sentences'] = all_sentences
        testcases['ancorra'] = all_ancorra_tags
        testcases['features'] = all_features
        with open('testfile.pkl', 'wb') as testfile:
            pickle.dump(testcases, testfile)
        print('testfile written')
# Out:
#   2%|▏         | 21/932 [00:00<00:04, 196.53it/s]
# processing files in directory:  /home/zubair/Documents/Work/Acads/Semester6/subjects/LData/Assignment/4/AnnCorra/Training
#  14%|█▎        | 128/932 [00:00<00:04, 179.84it/s]
# Error with sentence in file: /home/zubair/Documents/Work/Acads/Semester6/subjects/LData/Assignment/4/AnnCorra/Training/fullnews_id_2506477_date_7_6_2004.dat , no need to interfere
# Error with sentence in file: /home/zubair/Documents/Work/Acads/Semester6/subjects/LData/Assignment/4/AnnCorra/Training/fullnews_id_2506477_date_7_6_2004.dat , no need to interfere
# Error with sentence in file: /home/zubair/Documents/Work/Acads/Semester6/subjects/LData/Assignment/4/AnnCorra/Training/fullnews_id_2529450_date_16_6_2004.dat , no need to interfere
#  26%|██▌       | 243/932 [00:01<00:03, 179.14it/s]
# Error with sentence in file: /home/zubair/Documents/Work/Acads/Semester6/subjects/LData/Assignment/4/AnnCorra/Training/fullnews_id_2564256_date_1_7_2004.dat , no need to interfere
# 100%|██████████| 932/932 [00:05<00:00, 170.13it/s]
#  11%|█         | 12/112 [00:00<00:00, 119.78it/s]
# processing files in directory:  /home/zubair/Documents/Work/Acads/Semester6/subjects/LData/Assignment/4/AnnCorra/Development
# 100%|██████████| 112/112 [00:00<00:00, 130.82it/s]
#   8%|▊         | 11/131 [00:00<00:01, 73.23it/s]
# processing files in directory:  /home/zubair/Documents/Work/Acads/Semester6/subjects/LData/Assignment/4/AnnCorra/Testing
# 100%|██████████| 131/131 [00:01<00:00, 83.67it/s]
# testfile written

# %% [markdown]
# ## Testing some data

# %%
from wxconv import WXC
import difflib
converter = WXC(order='utf2wx')
with open('../AnnCorra/Training/fullnews_id_2575975_date_7_7_2004.dat', newline='') as csvfile:
    csvreader = csv.reader(csvfile, delimiter='\t')
    for row in csvreader:
        if len(row) > 0:
#             print(row)
#             print(row[1], row[2], row[7])
            word = row[1]
            base = row[2]
            print(word, base)
            word = converter.convert(word)
            base = converter.convert(base)
            diff = ''
            print(word, base)
            for i, s in enumerate(difflib.ndiff(base, word)):
                if s[0] == '+':
                    diff += s[-1]
            print(diff)
            print(''.join([s[-1] for s in difflib.ndiff(base, word) if s[0] == '+']))
# Out:
# वोल्कर वोल्कर
# volkara volkara
#
#
# कमेटी कमेटी
# kametI kametI
#
#
# पर पर
# para para
#
#
# भारत भारत
# BArawa BArawa
#
#
# में में
# meM meM
#
#
# मचे मच
# mace maca
# e
# e
# तूफान तूफान
# wUPAna wUPAna
#
#
# का का
# kA kA
#
#
# जो जो
# jo jo
#
#
# भी भी
# BI BI
#
#
# नतीजा नतीजा
# nawIjA nawIjA
#
#
# निकले निकल
# nikale nikala
# e
# e
# लेकिन लेकिन
# lekina lekina
#
#
# इस यह
# isa yaha
# is
# is
# रिपोर्ट रिपोर्ट
# riporta riporta
#
#
# को को
# ko ko
#
#
# लिखने लिख
# liKane liKa
# ne
# ne
# वाले वाला
# vAle vAlA
# e
# e
# पॉल पॉल
# pOYla pOYla
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# ने ने
# ne ne
#
#
# एक एक
# eka eka
#
#
# सनसनीखेज सनसनीखेज
# sanasanIKeja sanasanIKeja
#
#
# रहस्योद्घाटन रहस्योद्घाटन
# rahasyoxGAtana rahasyoxGAtana
#
#
# में में
# meM meM
#
#
# कहा कह
# kahA kaha
# A
# A
# है है
# hE hE
#
#
# कि कि
# ki ki
#
#
# वे वह
# ve vaha
# e
# e
# अपनी अपना
# apanI apanA
# I
# I
# रिपोर्ट रिपोर्ट
# riporta riporta
#
#
# की का
# kI kA
# I
# I
# भाषा भाषा
# BARA BARA
#
#
# में में
# meM meM
#
#
# परिवर्तन परिवर्तन
# parivarwana parivarwana
#
#
# को को
# ko ko
#
#
# तैयार तैयार
# wEyAra wEyAra
#
#
# हो हो
# ho ho
#
#
# गए जा
# gae jA
# gae
# gae
# हैं है
# hEM hE
# M
# M
# जिसमें जो
# jisameM jo
# isameM
# isameM
# संयुक्त संयुक्त
# saMyukwa saMyukwa
#
#
# राष्ट्र राष्ट्र
# rARtra rARtra
#
#
# के का
# ke kA
# e
# e
# महासचिव महासचिव
# mahAsaciva mahAsaciva
#
#
# कोफी कोफी
# koPI koPI
#
#
# अन्नान अन्नान
# annAna annAna
#
#
# के का
# ke kA
# e
# e
# पुत्र पुत्र
# puwra puwra
#
#
# कोजो कोजो
# kojo kojo
#
#
# अन्नान अन्नान
# annAna annAna
#
#
# के का
# ke kA
# e
# e
# कारोबार कारोबार
# kArobAra kArobAra
#
#
# का का
# kA kA
#
#
# जिक्र जिक्र
# jikra jikra
#
#
# है है
# hE hE
#
#
# । ।
# . .
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# ने ने
# ne ne
#
#
# इराकी इराकी
# irAkI irAkI
#
#
# तेल तेल
# wela wela
#
#
# के के
# ke ke
#
#
# बदले बदला
# baxale baxalA
# e
# e
# अनाज अनाज
# anAja anAja
#
#
# योजना योजना
# yojanA yojanA
#
#
# में में
# meM meM
#
#
# ६४ ६४
# 64 64
#
#
# अरब अरब
# araba araba
#
#
# अमेरिकी अमेरिकी
# amerikI amerikI
#
#
# डॉलर डॉलर
# dOYlara dOYlara
#
#
# के का
# ke kA
# e
# e
# घोटाले घोटाला
# GotAle GotAlA
# e
# e
# की का
# kI kA
# I
# I
# जाँच जाँच
# jAzca jAzca
#
#
# की कर
# kI kara
# I
# I
# है है
# hE hE
#
#
# । ।
# . .
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# ने ने
# ne ne
#
#
# कहा कह
# kahA kaha
# A
# A
# कि कि
# ki ki
#
#
# उन्हें वह
# unheM vaha
# uneM
# uneM
# यह यह
# yaha yaha
#
#
# पता पता
# pawA pawA
#
#
# नहीं नहीं
# nahIM nahIM
#
#
# था था
# WA WA
#
#
# कि कि
# ki ki
#
#
# १८ १८
# 18 18
#
#
# महीने महीना
# mahIne mahInA
# e
# e
# लंबी लंबा
# laMbI laMbA
# I
# I
# जाँच जाँच
# jAzca jAzca
#
#
# से से
# se se
#
#
# इस यह
# isa yaha
# is
# is
# विश्वस्तरीय विश्वस्तरीय
# viSvaswarIya viSvaswarIya
#
#
# संस्था संस्था
# saMsWA saMsWA
#
#
# का का
# kA kA
#
#
# घोटाला घोटाला
# GotAlA GotAlA
#
#
# कहाँ कहाँ
# kahAz kahAz
#
#
# तक तक
# waka waka
#
#
# खुलेगा खुल
# KulegA Kula
# egA
# egA
# और और
# Ora Ora
#
#
# वह वह
# vaha vaha
#
#
# इसके यह
# isake yaha
# iske
# iske
# नेता नेता
# newA newA
#
#
# महासचिव महासचिव
# mahAsaciva mahAsaciva
#
#
# कोफी कोफी
# koPI koPI
#
#
# अन्नान अन्नान
# annAna annAna
#
#
# की का
# kI kA
# I
# I
# कुर्सी कुर्सी
# kursI kursI
#
#
# हिलाने हिला
# hilAne hilA
# ne
# ne
# के का
# ke kA
# e
# e
# इतने इतना
# iwane iwanA
# e
# e
# नज़दीक नजदीक
# najZaxIka najaxIka
# Z
# Z
# पहुँच पहुँच
# pahuzca pahuzca
#
#
# जाएंगे जा
# jAeMge jA
# eMge
# eMge
# । ।
# . .
#
#
# ' SINGLE_QUOTE
# ' _SINGLE_QUOTE_
# '
# '
# लॉस लॉस
# lOYsa lOYsa
#
#
# एंजिल्स एंजिल्स
# eMjilsa eMjilsa
#
#
# टाइम्स टाइम्स
# tAimsa tAimsa
#
#
# ' SINGLE_QUOTE
# ' _SINGLE_QUOTE_
# '
# '
# को को
# ko ko
#
#
# दिए दे
# xie xe
# i
# i
# गए जा
# gae jA
# gae
# gae
# इंटरव्यू इंटरव्यू
# iMtaravyU iMtaravyU
#
#
# में में
# meM meM
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# ने ने
# ne ne
#
#
# कहा कह
# kahA kaha
# A
# A
# कि कि
# ki ki
#
#
# हालाँकि हालाँकि
# hAlAzki hAlAzki
#
#
# इसमें यह
# isameM yaha
# ismeM
# ismeM
# शुरुआत शुरुआत
# SuruAwa SuruAwa
#
#
# से से
# se se
#
#
# ही ही
# hI hI
#
#
# इतना इतना
# iwanA iwanA
#
#
# दम दम
# xama xama
#
#
# था था
# WA WA
#
#
# । ।
# . .
#
#
# लेकिन लेकिन
# lekina lekina
#
#
# यह यह
# yaha yaha
#
#
# जैसे जैसे
# jEse jEse
#
#
# ही ही
# hI hI
#
#
# जारी जारी
# jArI jArI
#
#
# हुई हो
# huI ho
# uI
# uI
# , COMMA
# , _COMMA_
# ,
# ,
# उन्हें वह
# unheM vaha
# uneM
# uneM
# आभास आभास
# ABAsa ABAsa
#
#
# हुआ हो
# huA ho
# uA
# uA
# कि कि
# ki ki
#
#
# अन्नान अन्नान
# annAna annAna
#
#
# का का
# kA kA
#
#
# काम काम
# kAma kAma
#
#
# उनके वह
# unake vaha
# unke
# unke
# शब्दों शब्द
# SabxoM Sabxa
# oM
# oM
# के के
# ke ke
#
#
# कारण कारण
# kAraNa kAraNa
#
#
# अधर अधर
# aXara aXara
#
#
# में में
# meM meM
#
#
# लटक लटक
# lataka lataka
#
#
# गया जा
# gayA jA
# gay
# gay
# है है
# hE hE
#
#
# । ।
# . .
#
#
# तब तब
# waba waba
#
#
# मैंने मैं
# mEMne mEM
# ne
# ne
# खुद खुद
# Kuxa Kuxa
#
#
# को को
# ko ko
#
#
# असहज असहज
# asahaja asahaja
#
#
# पाया पा
# pAyA pA
# yA
# yA
# । ।
# . .
#
#
# इस यह
# isa yaha
# is
# is
# अख़बार अखबार
# aKZabAra aKabAra
# Z
# Z
# के के
# ke ke
#
#
# मुताबिक़ मुताबिक
# muwAbikZa muwAbika
# Z
# Z
# सितंबर सितंबर
# siwaMbara siwaMbara
#
#
# २००५ २००५
# 2005 2005
#
#
# में में
# meM meM
#
#
# इस यह
# isa yaha
# is
# is
# रिपोर्ट रिपोर्ट
# riporta riporta
#
#
# के का
# ke kA
# e
# e
# मसविदे मसविदे
# masavixe masavixe
#
#
# के का
# ke kA
# e
# e
# प्रकाशन प्रकाशन
# prakASana prakASana
#
#
# से से
# se se
#
#
# चंद चंद
# caMxa caMxa
#
#
# घंटे घंटा
# GaMte GaMtA
# e
# e
# पहले पहले
# pahale pahale
#
#
# कोफी कोफी
# koPI koPI
#
#
# अन्नान अन्नान
# annAna annAna
#
#
# और और
# Ora Ora
#
#
# उनके वह
# unake vaha
# unke
# unke
# वकील वकील
# vakIla vakIla
#
#
# ने ने
# ne ne
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# से से
# se se
#
#
# कहा कह
# kahA kaha
# A
# A
# कि कि
# ki ki
#
#
# वह वह
# vaha vaha
#
#
# कोजो कोजो
# kojo kojo
#
#
# अन्नान अन्नान
# annAna annAna
#
#
# के का
# ke kA
# e
# e
# कारोबार कारोबार
# kArobAra kArobAra
#
#
# पर पर
# para para
#
#
# रिपोर्ट रिपोर्ट
# riporta riporta
#
#
# में में
# meM meM
#
#
# प्रयोग प्रयोग
# prayoga prayoga
#
#
# की कर
# kI kara
# I
# I
# गई जा
# gaI jA
# gaI
# gaI
# भाषा भाषा
# BARA BARA
#
#
# को को
# ko ko
#
#
# बदलें बदल
# baxaleM baxala
# eM
# eM
# । ।
# . .
#
#
# क्योंकि क्योंकि
# kyoMki kyoMki
#
#
# कोफी कोफी
# koPI koPI
#
#
# और और
# Ora Ora
#
#
# उनके वह
# unake vaha
# unke
# unke
# वकील वकील
# vakIla vakIla
#
#
# का का
# kA kA
#
#
# मानना मान
# mAnanA mAna
# nA
# nA
# था था
# WA WA
#
#
# कि कि
# ki ki
#
#
# रिपोर्ट रिपोर्ट
# riporta riporta
#
#
# में में
# meM meM
#
#
# जिस जो
# jisa jo
# isa
# isa
# भाषा भाषा
# BARA BARA
#
#
# का का
# kA kA
#
#
# इस्तेमाल इस्तेमाल
# iswemAla iswemAla
#
#
# किया कर
# kiyA kara
# iyA
# iyA
# गया जा
# gayA jA
# gay
# gay
# है है
# hE hE
#
#
# , COMMA
# , _COMMA_
# ,
# ,
# उससे वह
# usase vaha
# usse
# usse
# संयुक्त संयुक्त
# saMyukwa saMyukwa
#
#
# राष्ट्र राष्ट्र
# rARtra rARtra
#
#
# महासचिव महासचिव
# mahAsaciva mahAsaciva
#
#
# को को
# ko ko
#
#
# बाध्य बाध्य
# bAXya bAXya
#
#
# होकर हो
# hokara ho
# kara
# kara
# इस्तीफा इस्तीफा
# iswIPA iswIPA
#
#
# देना दे
# xenA xe
# nA
# nA
# पड़ेगा पड़
# padZegA padZa
# egA
# egA
# । ।
# . .
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# ने ने
# ne ne
#
#
# अखबार अखबार
# aKabAra aKabAra
#
#
# को को
# ko ko
#
#
# बताया बता
# bawAyA bawA
# yA
# yA
# कि कि
# ki ki
#
#
# वे वह
# ve vaha
# e
# e
# तैयार तैयार
# wEyAra wEyAra
#
#
# हो हो
# ho ho
#
#
# गए जा
# gae jA
# gae
# gae
# । ।
# . .
#
#
# क्योंकि क्योंकि
# kyoMki kyoMki
#
#
# वह वह
# vaha vaha
#
#
# सारी सारा
# sArI sArA
# I
# I
# प्रक्रिया प्रक्रिया
# prakriyA prakriyA
#
#
# का का
# kA kA
#
#
# मामूली मामूली
# mAmUlI mAmUlI
#
#
# हिस्सा हिस्सा
# hissA hissA
#
#
# था था
# WA WA
#
#
# । ।
# . .
#
#
# बहरहाल बहरहाल
# baharahAla baharahAla
#
#
# , COMMA
# , _COMMA_
# ,
# ,
# सितंबर सितंबर
# siwaMbara siwaMbara
#
#
# में में
# meM meM
#
#
# रिपोर्ट रिपोर्ट
# riporta riporta
#
#
# जारी जारी
# jArI jArI
#
#
# करने कर
# karane kara
# ne
# ne
# से से
# se se
#
#
# पहले पहले
# pahale pahale
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# कोफी कोफी
# koPI koPI
#
#
# अन्नान अन्नान
# annAna annAna
#
#
# और और
# Ora Ora
#
#
# उनके वह
# unake vaha
# unke
# unke
# वकील वकील
# vakIla vakIla
#
#
# से से
# se se
#
#
# इस यह
# isa yaha
# is
# is
# मुद्दे मुद्दा
# muxxe muxxA
# e
# e
# पर पर
# para para
#
#
# बातचीत बातचीत
# bAwacIwa bAwacIwa
#
#
# के के
# ke ke
#
#
# लिए लिए
# lie lie
#
#
# मिले मिल
# mile mila
# e
# e
# । ।
# . .
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# ने ने
# ne ne
#
#
# बताया बता
# bawAyA bawA
# yA
# yA
# कि कि
# ki ki
#
#
# हमने हम
# hamane hama
# ne
# ne
# रिपोर्ट रिपोर्ट
# riporta riporta
#
#
# में में
# meM meM
#
#
# जिस जो
# jisa jo
# isa
# isa
# भाषा भाषा
# BARA BARA
#
#
# का का
# kA kA
#
#
# इस्तेमाल इस्तेमाल
# iswemAla iswemAla
#
#
# किया कर
# kiyA kara
# iyA
# iyA
# , COMMA
# , _COMMA_
# ,
# ,
# उसमें वह
# usameM vaha
# usmeM
# usmeM
# कहा कह
# kahA kaha
# A
# A
# गया जा
# gayA jA
# gay
# gay
# था था
# WA WA
#
#
# कि कि
# ki ki
#
#
# संयुक्त संयुक्त
# saMyukwa saMyukwa
#
#
# राष्ट्र राष्ट्र
# rARtra rARtra
#
#
# के का
# ke kA
# e
# e
# मानक मानक
# mAnaka mAnaka
#
#
# पर पर
# para para
#
#
# अन्नान अन्नान
# annAna annAna
#
#
# की का
# kI kA
# I
# I
# क्षमता क्षमता
# kRamawA kRamawA
#
#
# खरी खरा
# KarI KarA
# I
# I
# नहीं नहीं
# nahIM nahIM
#
#
# उतरती उतर
# uwarawI uwara
# wI
# wI
# । ।
# . .
#
#
# इसके यह
# isake yaha
# iske
# iske
# आगे आगे
# Age Age
#
#
# इसी यह
# isI yaha
# isI
# isI
# तरह तरह
# waraha waraha
#
#
# की का
# kI kA
# I
# I
# कुछ कुछ
# kuCa kuCa
#
#
# और और
# Ora Ora
#
#
# बातें बात
# bAweM bAwa
# eM
# eM
# उसी वह
# usI vaha
# usI
# usI
# भाषा भाषा
# BARA BARA
#
#
# में में
# meM meM
#
#
# थीं था
# WIM WA
# IM
# IM
# । ।
# . .
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# से से
# se se
#
#
# यह यह
# yaha yaha
#
#
# बातचीत बातचीत
# bAwacIwa bAwacIwa
#
#
# पिछले पिछला
# piCale piCalA
# e
# e
# बृहस्पतिवार बृहस्पतिवार
# bqhaspawivAra bqhaspawivAra
#
#
# को को
# ko ko
#
#
# की कर
# kI kara
# I
# I
# गई जा
# gaI jA
# gaI
# gaI
# थी था
# WI WA
# I
# I
# , COMMA
# , _COMMA_
# ,
# ,
# जिस जो
# jisa jo
# isa
# isa
# दिन दिन
# xina xina
#
#
# भारत भारत
# BArawa BArawa
#
#
# के का
# ke kA
# e
# e
# विदेश विदेश
# vixeSa vixeSa
#
#
# मंत्री मंत्री
# maMwrI maMwrI
#
#
# नटवर नटवर
# natavara natavara
#
#
# सिंह सिंह
# siMha siMha
#
#
# और और
# Ora Ora
#
#
# कांग्रेस कांग्रेस
# kAMgresa kAMgresa
#
#
# पार्टी पार्टी
# pArtI pArtI
#
#
# का का
# kA kA
#
#
# नाम नाम
# nAma nAma
#
#
# आया आ
# AyA A
# yA
# yA
# था था
# WA WA
#
#
# । ।
# . .
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# से से
# se se
#
#
# पूछा पूछ
# pUCA pUCa
# A
# A
# गया जा
# gayA jA
# gay
# gay
# था था
# WA WA
#
#
# कि कि
# ki ki
#
#
# क्या क्या
# kyA kyA
#
#
# कोजो कोजो
# kojo kojo
#
#
# ने ने
# ne ne
#
#
# अपने अपना
# apane apanA
# e
# e
# पिता पिता
# piwA piwA
#
#
# के का
# ke kA
# e
# e
# संबंधों संबंध
# saMbaMXoM saMbaMXa
# oM
# oM
# का का
# kA kA
#
#
# इस्तेमाल इस्तेमाल
# iswemAla iswemAla
#
#
# अपनी अपना
# apanI apanA
# I
# I
# कंपनी कंपनी
# kaMpanI kaMpanI
#
#
# को को
# ko ko
#
#
# लाभ लाभ
# lABa lABa
#
#
# पहुंचाने पहुंचा
# pahuMcAne pahuMcA
# ne
# ne
# के के
# ke ke
#
#
# लिए लिए
# lie lie
#
#
# किया कर
# kiyA kara
# iyA
# iyA
# था था
# WA WA
#
#
# । ।
# . .
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# ने ने
# ne ne
#
#
# कहा कह
# kahA kaha
# A
# A
# , COMMA
# , _COMMA_
# ,
# ,
# आज आज
# Aja Aja
#
#
# दिन दिन
# xina xina
#
#
# तक तक
# waka waka
#
#
# मुझे मैं
# muJe mEM
# uJe
# uJe
# इसकी यह
# isakI yaha
# iskI
# iskI
# कोई कोई
# koI koI
#
#
# जानकारी जानकारी
# jAnakArI jAnakArI
#
#
# नहीं नहीं
# nahIM nahIM
#
#
# है है
# hE hE
#
#
# । ।
# . .
#
#
# अन्नान अन्नान
# annAna annAna
#
#
# के का
# ke kA
# e
# e
# वकील वकील
# vakIla vakIla
#
#
# ग्रेगरी ग्रेगरी
# gregarI gregarI
#
#
# क्रेग क्रेग
# krega krega
#
#
# ने ने
# ne ne
#
#
# कहा कह
# kahA kaha
# A
# A
# कि कि
# ki ki
#
#
# इस यह
# isa yaha
# is
# is
# रिपोर्ट रिपोर्ट
# riporta riporta
#
#
# के का
# ke kA
# e
# e
# नतीजे नतीजा
# nawIje nawIjA
# e
# e
# पर पर
# para para
#
#
# तो तो
# wo wo
#
#
# कार्रवाई कार्रवाई
# kArravAI kArravAI
#
#
# अलग अलग
# alaga alaga
#
#
# से से
# se se
#
#
# होगी हो
# hogI ho
# gI
# gI
# , COMMA
# , _COMMA_
# ,
# ,
# क्योंकि क्योंकि
# kyoMki kyoMki
#
#
# कोफी कोफी
# koPI koPI
#
#
# ने ने
# ne ne
#
#
# प्रबंधन प्रबंधन
# prabaMXana prabaMXana
#
#
# संबंधी संबंधी
# saMbaMXI saMbaMXI
#
#
# मुद्दों मुद्दा
# muxxoM muxxA
# oM
# oM
# की का
# kI kA
# I
# I
# जानकारी जानकारी
# jAnakArI jAnakArI
#
#
# ली ले
# lI le
# I
# I
# है है
# hE hE
#
#
# । ।
# . .
#
#
# लेकिन लेकिन
# lekina lekina
#
#
# वे वह
# ve vaha
# e
# e
# अपने अपना
# apane apanA
# e
# e
# पुत्र पुत्र
# puwra puwra
#
#
# के का
# ke kA
# e
# e
# बर्ताव बर्ताव
# barwAva barwAva
#
#
# की का
# kI kA
# I
# I
# जिम्मेदारी जिम्मेदारी
# jimmexArI jimmexArI
#
#
# नहीं नहीं
# nahIM nahIM
#
#
# ले ले
# le le
#
#
# सकते सक
# sakawe saka
# we
# we
# , COMMA
# , _COMMA_
# ,
# ,
# क्योंकि क्योंकि
# kyoMki kyoMki
#
#
# उसकी वह
# usakI vaha
# uskI
# uskI
# उन्हें वह
# unheM vaha
# uneM
# uneM
# जानकारी जानकारी
# jAnakArI jAnakArI
#
#
# ही ही
# hI hI
#
#
# नहीं नहीं
# nahIM nahIM
#
#
# थी था
# WI WA
# I
# I
# । ।
# . .
#
#
# कुल कुल
# kula kula
#
#
# मिलाकर मिला
# milAkara milA
# kara
# kara
# वोल्कर वोल्कर
# volkara volkara
#
#
# मान मान
# mAna mAna
#
#
# गए जा
# gae jA
# gae
# gae
# । ।
# . .
#
#
# यद्यपि यद्यपि
# yaxyapi yaxyapi
#
#
# उन्हें वह
# unheM vaha
# uneM
# uneM
# इस यह
# isa yaha
# is
# is
# बात बात
# bAwa bAwa
#
#
# पर पर
# para para
#
#
# शक़ शक
# SakZa Saka
# Z
# Z
# था था
# WA WA
#
#
# कि कि
# ki ki
#
#
# अन्नान अन्नान
# annAna annAna
#
#
# ' SINGLE_QUOTE
# ' _SINGLE_QUOTE_
# '
# '
# कोटेसना कोटेसना
# kotesanA kotesanA
#
#
# ' SINGLE_QUOTE
# ' _SINGLE_QUOTE_
# '
# '
# की का
# kI kA
# I
# I
# निविदा निविदा
# nivixA nivixA
#
#
# के के
# ke ke
#
#
# बारे बारे
# bAre bAre
#
#
# में में
# meM meM
#
#
# वाकई वाकई
# vAkaI vAkaI
#
#
# नहीं नहीं
# nahIM nahIM
#
#
# जानते जान
# jAnawe jAna
# we
# we
# लेकिन लेकिन
# lekina lekina
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# इस यह
# isa yaha
# is
# is
# बात बात
# bAwa bAwa
#
#
# से से
# se se
#
#
# सहमत सहमत
# sahamawa sahamawa
#
#
# थे था
# We WA
# e
# e
# कि कि
# ki ki
#
#
# अन्नान अन्नान
# annAna annAna
#
#
# ने ने
# ne ne
#
#
# कोटेसना कोटेसना
# kotesanA kotesanA
#
#
# की का
# kI kA
# I
# I
# निविदा निविदा
# nivixA nivixA
#
#
# पास पास
# pAsa pAsa
#
#
# कराने करा
# karAne karA
# ne
# ne
# के के
# ke ke
#
#
# लिए लिए
# lie lie
#
#
# किसी कोई
# kisI koI
# is
# is
# प्रभाव प्रभाव
# praBAva praBAva
#
#
# का का
# kA kA
#
#
# इस्तेमाल इस्तेमाल
# iswemAla iswemAla
#
#
# नहीं नहीं
# nahIM nahIM
#
#
# किया कर
# kiyA kara
# iyA
# iyA
# । ।
# . .
#
#
# किसी कोई
# kisI koI
# is
# is
# संयुक्त संयुक्त
# saMyukwa saMyukwa
#
#
# राष्ट्र राष्ट्र
# rARtra rARtra
#
#
# महासचिव महासचिव
# mahAsaciva mahAsaciva
#
#
# को को
# ko ko
#
#
# कुर्सी कुर्सी
# kursI kursI
#
#
# से से
# se se
#
#
# गिराने गिरा
# girAne girA
# ne
# ne
# का का
# kA kA
#
#
# कोई कोई
# koI koI
#
#
# तुक़ तुक
# wukZa wuka
# Z
# Z
# भी भी
# BI BI
#
#
# नहीं नहीं
# nahIM nahIM
#
#
# था था
# WA WA
#
#
# । ।
# . .
#
#
# वोल्कर वोल्कर
# volkara volkara
#
#
# ने ने
# ne ne
#
#
# कहा कह
# kahA kaha
# A
# A
# कि कि
# ki ki
#
#
# जांच जांच
# jAMca jAMca
#
#
# के के
# ke ke
#
#
# दौरान दौरान
# xOrAna xOrAna
#
#
# किसी कोई
# kisI koI
# is
# is
# ने ने
# ne ne
#
#
# उन्हें वह
# unheM vaha
# uneM
# uneM
# बताया बता
# bawAyA bawA
# yA
# yA
# भी भी
# BI BI
#
#
# नहीं नहीं
# nahIM nahIM
#
#
# कि कि
# ki ki
#
#
# निविदा निविदा
# nivixA nivixA
#
#
# की का
# kI kA
# I
# I
# सारी सारा
# sArI sArA
# I
# I
# प्रक्रिया प्रक्रिया
# prakriyA prakriyA
#
#
# पर पर
# para para
#
#
# किसी कोई
# kisI koI
# is
# is
# ने ने
# ne ne
#
#
# प्रभाव प्रभाव
# praBAva praBAva
#
#
# डालने डाल
# dAlane dAla
# ne
# ne
# की का
# kI kA
# I
# I
# कोशिश कोशिश
# koSiSa koSiSa
#
#
# की कर
# kI kara
# I
# I
# या या
# yA yA
#
#
# इस यह
# isa yaha
# is
# is
# पर पर
# para para
#
#
# विचार विचार
# vicAra vicAra
#
#
# भी भी
# BI BI
#
#
# किया कर
# kiyA kara
# iyA
# iyA
# गया जा
# gayA jA
# gay
# gay
# । ।
# . .
#
#
# इस यह
# isa yaha
# is
# is
# तरह तरह
# waraha waraha
#
#
# का का
# kA kA
#
#
# कोई कोई
# koI koI
#
#
# सुबूत सुबूत
# subUwa subUwa
#
#
# भी भी
# BI BI
#
#
# नहीं नहीं
# nahIM nahIM
#
#
# मिला मिल
# milA mila
# A
# A
# । ।
# . .

# %%
# with open('Data/Testing_features.pkl', 'rb') as pickled:
#     newlist = pickle.load(pickled)
# print(len(newlist))
# print(newlist[3])
# Out:
# 1804
# [{'pos': 'PRP', 'word': 'उन्होंने', 'cat': 'pn', 'gen': 'any', 'num': 'sg', 'pers': '3h', 'case': 'o', 'vib': 'ने', 'tam': 'ne', 'chunkId': 'NP', 'chunkType': 'head', 'stype': '', 'voicetype': ''}, {'pos': 'VM', 'word': 'बताया', 'cat': 'v', 'gen': 'm', 'num': 'sg', 'pers': 'any', 'case': '', 'vib': 'या', 'tam': 'yA', 'chunkId': 'VGF', 'chunkType': 'head', 'stype': 'declarative', 'voicetype': 'active'}, {'pos': 'CC', 'word': 'कि', 'cat': 'avy', 'gen': '', 'num': '', 'pers': '', 'case': '', 'vib': '', 'tam': '', 'chunkId': 'CCP', 'chunkType': 'head', 'stype': '', 'voicetype': ''}, {'pos': 'DEM', 'word': 'ये', 'cat': 'pn', 'gen': 'any', 'num': 'pl', 'pers': '3', 'case': 'd', 'vib': '', 'tam': '', 'chunkId': 'NP2', 'chunkType': 'child', 'stype': '', 'voicetype': ''}, {'pos': 'NN', 'word': 'लोग', 'cat': 'n', 'gen': 'm', 'num': 'pl', 'pers': '3', 'case': 'd', 'vib': '0', 'tam': '0', 'chunkId': 'NP2', 'chunkType': 'head', 'stype': '', 'voicetype': ''}, {'pos': 'NNP', 'word': 'जुहू', 'cat': 'n', 'gen': 'm', 'num': 'sg', 'pers': '3', 'case': 'd', 'vib': '0', 'tam': '0', 'chunkId': 'NP3', 'chunkType': 'head', 'stype': '', 'voicetype': ''}, {'pos': 'JJ', 'word': 'स्थित', 'cat': 'adj', 'gen': 'any', 'num': 'any', 'pers': '', 'case': 'o', 'vib': '', 'tam': '', 'chunkId': 'JJP', 'chunkType': 'head', 'stype': '', 'voicetype': ''}, {'pos': 'NNPC', 'word': 'कॉपर', 'cat': 'n', 'gen': 'm', 'num': 'sg', 'pers': '3', 'case': 'd', 'vib': '0', 'tam': '0', 'chunkId': 'NP4', 'chunkType': 'child', 'stype': '', 'voicetype': ''}, {'pos': 'NNPC', 'word': 'चिमनी', 'cat': 'n', 'gen': 'f', 'num': 'sg', 'pers': '3', 'case': 'd', 'vib': '0', 'tam': '0', 'chunkId': 'NP4', 'chunkType': 'child', 'stype': '', 'voicetype': ''}, {'pos': 'NNP', 'word': 'रेस्टोरेंट', 'cat': 'n', 'gen': 'm', 'num': 'sg', 'pers': '3', 'case': 'o', 'vib': '0_के_बाहर', 'tam': '0', 'chunkId': 'NP4', 'chunkType': 'head', 'stype': '', 'voicetype': ''}, {'pos': 'PSP', 'word': 'के', 'cat': 'psp', 'gen': '', 'num': '', 'pers': '', 'case': '', 'vib': '', 'tam': '', 'chunkId': 'NP4', 'chunkType': 'child', 'stype': '', 'voicetype': ''}, {'pos': 'NST', 'word': 'बाहर', 'cat': 'nst', 'gen': 'm', 'num': 'sg', 'pers': '3', 'case': 'd', 'vib': '', 'tam': '', 'chunkId': 'NP4', 'chunkType': 'child', 'stype': '', 'voicetype': ''}, {'pos': 'NNPC', 'word': 'रिलायंस', 'cat': 'n', 'gen': 'm', 'num': 'sg', 'pers': '3', 'case': 'd', 'vib': '0', 'tam': '0', 'chunkId': 'NP5', 'chunkType': 'child', 'stype': '', 'voicetype': ''}, {'pos': 'NNP', 'word': 'एनर्जी', 'cat': 'n', 'gen': 'f', 'num': 'sg', 'pers': '3', 'case': 'o', 'vib': '0_का', 'tam': '0', 'chunkId': 'NP5', 'chunkType': 'head', 'stype': '', 'voicetype': ''}, {'pos': 'PSP', 'word': 'के', 'cat': 'psp', 'gen': 'm', 'num': 'sg', 'pers': '', 'case': 'o', 'vib': '', 'tam': '', 'chunkId': 'NP5', 'chunkType': 'child', 'stype': '', 'voicetype': ''}, {'pos': 'JJC', 'word': 'नक़दी', 'cat': 'n', 'gen': 'f', 'num': 'sg', 'pers': '3', 'case': 'd', 'vib': '0', 'tam': '0', 'chunkId': 'NP6', 'chunkType': 'child', 'stype': '', 'voicetype': ''}, {'pos': 'JJ', 'word': 'जमा', 'cat': 'adj', 'gen': 'any', 'num': 'any', 'pers': '', 'case': 'o', 'vib': '', 'tam': '', 'chunkId': 'NP6', 'chunkType': 'child', 'stype': '', 'voicetype': ''}, {'pos': 'NN', 'word': 'केंद्र', 'cat': 'n', 'gen': 'm', 'num': 'sg', 'pers': '3', 'case': 'o', 'vib': '0_को', 'tam': '0', 'chunkId': 'NP6', 'chunkType': 'head', 'stype': '', 'voicetype': ''}, {'pos': 'PSP', 'word': 'को', 'cat': 'psp', 'gen': '', 'num': '', 'pers': '', 'case': '', 'vib': '', 'tam': '', 'chunkId': 'NP6', 'chunkType': 'child', 'stype': '', 'voicetype': ''}, {'pos': 'VM', 'word': 'लूटने', 'cat': 'v', 'gen': 'any', 'num': 'sg', 'pers': 'any', 'case': 'o', 'vib': 'ना_का', 'tam': 'nA', 'chunkId': 'VGNN', 'chunkType': 'head', 'stype': '', 'voicetype': ''}, {'pos': 'PSP', 'word': 'की', 'cat': 'psp', 'gen': 'f', 'num': 'sg', 'pers': '', 'case': 'o', 'vib': '', 'tam': '', 'chunkId': 'VGNN', 'chunkType': 'child', 'stype': '', 'voicetype': ''}, ...
